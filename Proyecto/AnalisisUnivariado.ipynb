# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_excel(r'D:\Programacion\Python\ProgramacionParaAnalisisDeDatos\Proyecto\nuclear-energy-generation.xlsx', sheet_name = 0)
df_backup = df.copy()

# %%
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2109 entries, 0 to 2108
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Entity                2109 non-null   object
#  1   Code                  2109 non-null   object
#  2   Year                  2109 non-null   int64
#  3   Nuclear_Electricity   2109 non-null   float64
#  4   Annual_CO2_emissions  2109 non-null   float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 82.5+ KB
#          Entity      Code  Year  Nuclear_Electricity  Annual_CO2_emissions
# 0     Argentina       ARG  1965                 0.00              2.666444
# 1     Argentina       ARG  1966                 0.00              2.815352
# 2     Argentina       ARG  1967                 0.00              2.877178
# 3     Argentina       ARG  1968                 0.00              2.985735
# ...

# %%
col = df.columns
col
# Out:
# Index(['Entity', 'Code', 'Year', 'Nuclear_Electricity',
#        'Annual_CO2_emissions'],
#       dtype='object')

# %%
nominales = ['Entity', 'Code']
intervalo = ['Year']
razon = ['Nuclear_Electricity', 'Annual_CO2_emissions']

# %%
df['Entity'] = df['Entity'].astype('category')
df['Code'] = df['Code'].astype('category')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2109 entries, 0 to 2108
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Entity                2109 non-null   category
#  1   Code                  2109 non-null   category
#  2   Year                  2109 non-null   int64
#  3   Nuclear_Electricity   2109 non-null   float64
#  4   Annual_CO2_emissions  2109 non-null   float64
# dtypes: category(2), float64(2), int64(1)
# memory usage: 56.3 KB

# %%
for i in nominales:
    print(i)
    print(df[i].unique())
# Out:
# Entity
# ['Argentina', 'Armenia', 'Belarus', 'Belgium', 'Brazil', ..., 'Ukraine', 'United Arab Emirates', 'United Kingdom', 'United States', 'World']
# Length: 37
# Categories (37, object): ['Argentina', 'Armenia', 'Belarus', 'Belgium', ..., 'United Arab Emirates', 'United Kingdom', 'United States', 'World']
# Code
# ['ARG', 'ARM', 'BLR', 'BEL', 'BRA', ..., 'UKR', 'ARE', 'GBR', 'USA', 'OWID_WRL']
# Length: 37
# Categories (37, object): ['ARE', 'ARG', 'ARM', 'BEL', ..., 'TWN', 'UKR', 'USA', 'ZAF']

# %%
Entities = df.Entity.value_counts()
Entities
# Out:
# Argentina               57
# Mexico                  57
# Pakistan                57
# Romania                 57
# Russia                  57
# Slovakia                57
# Slovenia                57
# South Africa            57
# South Korea             57
# Spain                   57
# Sweden                  57
# Switzerland             57
# Taiwan                  57
# Ukraine                 57
# United Arab Emirates    57
# United Kingdom          57
# United States           57
# Netherlands             57
# Lithuania               57
# Armenia                 57
# Kazakhstan              57
# Belarus                 57
# Belgium                 57
# Brazil                  57
# Bulgaria                57
# Canada                  57
# China                   57
# Czechia                 57
# Finland                 57
# France                  57
# Germany                 57
# Hungary                 57
# India                   57
# Iran                    57
# ...

# %%
for country in Entities:
    formatedData = df.loc[df['Entity'] == country]
    plt.figure()
    sns.histplot(data = formatedData, y = 'Annual_CO2_emissions', x = 'Year', kde = True).set(title=country)
# Out:
# C:\Users\david\AppData\Local\Temp\ipykernel_64708\297530457.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure()

# %%
for country in Entities:
    formatedData = df.loc[df['Entity'] == country]
    plt.figure()
    sns.histplot(data = formatedData, y = 'Nuclear_Electricity', x = 'Year', kde = True).set(title=country)
# Out:
# C:\Users\david\AppData\Local\Temp\ipykernel_64708\2661495800.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure()

# %%
AritmeticOPerations = df.groupby(by='Entity')['Nuclear_Electricity','Annual_CO2_emissions']
# Out:
# C:\Users\david\AppData\Local\Temp\ipykernel_64708\2849249711.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   AritmeticOPerations = df.groupby(by='Entity')['Nuclear_Electricity','Annual_CO2_emissions']

# %%
AritmeticOPerations.mean()
# Out:
#                       Nuclear_Electricity  Annual_CO2_emissions
# Entity
# Argentina                        4.977175              3.799055
# Armenia                          0.850526              1.881491
# Belarus                         14.399708              7.510111
# Belgium                         30.501860             11.442265
# Brazil                           5.642649              1.676097
# Bulgaria                        11.684579              7.335813
# Canada                          62.099263             16.505319
# China                           54.450667              3.329578
# Czechia                         13.149123             13.840003
# Finland                         15.655494             10.135981
# France                         264.642491              7.277892
# Germany                         98.327789             11.754664
# Hungary                          9.222368              6.339608
# India                           13.317485              0.858944
# ...

# %%
AritmeticOPerations.sum()
# Out:
#                       Nuclear_Electricity  Annual_CO2_emissions
# Entity
# Argentina                      283.699000            216.546118
# Armenia                         48.480000            107.244963
# Belarus                        820.783342            428.076306
# Belgium                       1738.606000            652.209084
# Brazil                         321.631000             95.537544
# Bulgaria                       666.021000            418.141355
# Canada                        3539.657995            940.803165
# China                         3103.688000            189.785949
# Czechia                        749.500000            788.880152
# Finland                        892.363157            577.750918
# France                       15084.622000            414.839840
# Germany                       5604.684000            670.015855
# Hungary                        525.675000            361.357681
# India                          759.096632             48.959800
# ...

# %%
AritmeticOPerations.min()
# Out:
#                       Nuclear_Electricity  Annual_CO2_emissions
# Entity
# Argentina                        0.000000              2.666444
# Armenia                          0.000000              0.744803
# Belarus                          0.000000              5.293781
# Belgium                          0.000000              7.816142
# Brazil                           0.000000              0.664164
# Bulgaria                         0.000000              5.296769
# Canada                           0.128000             12.794933
# China                            0.000000              0.604760
# Czechia                          0.000000              8.722278
# Finland                          0.000000              5.542695
# France                           0.897000              4.342917
# Germany                          0.117000              7.672972
# Hungary                          0.000000              4.407595
# India                            0.000000              0.305670
# ...

# %%
AritmeticOPerations.max()
# Out:
#                       Nuclear_Electricity  Annual_CO2_emissions
# Entity
# Argentina                        10.17000              4.670683
# Armenia                           2.57000              2.761147
# Belarus                         143.79843             11.900442
# Belgium                          50.33000             14.251578
# Brazil                           15.17000              2.742072
# Bulgaria                         20.22000             10.295022
# Canada                          107.08421             18.469010
# China                           407.50000              8.045740
# Czechia                          30.75000             18.386303
# Finland                          23.87000             13.937167
# France                          451.53000             10.396503
# Germany                         171.30000             14.347402
# Hungary                          16.29000              8.558931
# India                            45.16000              1.925088
# ...

# %%
values = ['World']
df2 = df[df.Entity.isin(values) == False]
df2
# Out:
#              Entity Code  Year  Nuclear_Electricity  Annual_CO2_emissions
# 0         Argentina  ARG  1965                 0.00              2.666444
# 1         Argentina  ARG  1966                 0.00              2.815352
# 2         Argentina  ARG  1967                 0.00              2.877178
# 3         Argentina  ARG  1968                 0.00              2.985735
# 4         Argentina  ARG  1969                 0.00              3.291103
# ...             ...  ...   ...                  ...                   ...
# 2047  United States  USA  2017               804.95             15.800776
# 2048  United States  USA  2018               807.08             16.187923
# 2049  United States  USA  2019               809.41             15.730885
# 2050  United States  USA  2020               789.88             14.037217
# 2051  United States  USA  2021               778.19             14.858668
#
# [2052 rows x 5 columns]

# %%
for country in Entities:

    fig,ax = plt.subplots(figsize=(20,30))
    formatedData = df.loc[df['Entity'] == country]
    #sns.boxplot( x=df2["Nuclear_Electricity"], y=df2["Entity"], palette="Blues");
    plt.figure()
    sns.boxplot(data=formatedData, palette='Set3', linewidth=1.2, fliersize=2, flierprops=dict(marker='o', markersize=4), x="Nuclear_Electricity", y="Entity")
# Out:
# C:\Users\david\AppData\Local\Temp\ipykernel_64708\2165914951.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig,ax = plt.subplots(figsize=(20,30))
